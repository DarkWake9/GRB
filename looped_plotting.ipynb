# %%
#import statements
import grblc
import grblc.fitting.io as io
from grblc.fitting import Model, Lightcurve
import numpy as np
import glob2
import pandas as pd
from IPython.display import display, Markdown
import emcee
import matplotlib.pyplot as plt
import glob
import re
import os
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /media/darkwake/VIB2/GRB/looped_plotting.ipynb Cell 1 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/media/darkwake/VIB2/GRB/looped_plotting.ipynb#ch0000000?line=0'>1</a> #import statements
# ----> <a href='vscode-notebook-cell:/media/darkwake/VIB2/GRB/looped_plotting.ipynb#ch0000000?line=1'>2</a> import grblc
#       <a href='vscode-notebook-cell:/media/darkwake/VIB2/GRB/looped_plotting.ipynb#ch0000000?line=2'>3</a> import grblc.fitting.io as io
#       <a href='vscode-notebook-cell:/media/darkwake/VIB2/GRB/looped_plotting.ipynb#ch0000000?line=3'>4</a> from grblc.fitting import Model, Lightcurve
#
# ModuleNotFoundError: No module named 'grblc'

# %%
path = 'C:/Users/dmxle/OneDrive/Documents/SULI_2022/webpage/mainsample/mainsample_flux/'
path2 = 'C:/Users/dmxle/Downloads/mastersample_sam/mastersample/'
path3 = 'C:/Users/dmxle/Downloads/flux2flux/'

# %% [markdown]
# ## plotting all current approved LCs

# %%
#plotting flux-flux conversions round 1

path5 = 'C:/Users/dmxle/OneDrive/Documents/SULI_2022/webpage/mainsample/correct_mastersample_179/'


for filename in os.listdir(path5):
    
#     GRB = get_numbers_from_filename(filename)[0]
    
    data = np.loadtxt(path5+filename, skiprows=1, usecols = (0, 1, 2)) 
        
    logtime = np.log10(data[:, 0])
    logflux = np.log10(data[:, 1])
    fluxerr = data[:, 2]
    logfluxerr = fluxerr/(np.log(10)*data[:, 1]) 

    plt.figure() 
    plt.scatter(logtime, logflux)
    plt.xlabel('log time (s)')
    plt.ylabel('log flux (erg/s*cm^2)')
    plt.title(filename)
# Out:
# C:\Users\dmxle\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# C:\Users\dmxle\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: RuntimeWarning: invalid value encountered in log10
#   del sys.path[0]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_56696/232514057.py in <module>
#       8 #     GRB = get_numbers_from_filename(filename)[0]
#       9
# ---> 10     data = np.loadtxt(path5+filename, skiprows=1, usecols = (0, 1, 2))
#      11
#      12     logtime = np.log10(data[:, 0])
#
# ...
